# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
import keras_tuner as kt
from tensorflow import keras

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data/weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
df = df.drop(['Evaporation','Sunshine','Cloud9am','Cloud3pm','Location','Date'],axis = 1)

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0     13.4     22.9       0.6           W           44.0          W
# 1      7.4     25.1       0.0         WNW           44.0        NNW
# 2     12.9     25.7       0.0         WSW           46.0          W
# 3      9.2     28.0       0.0          NE           24.0         SE
# 4     17.5     32.3       1.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       1007.7       1007.1     16.9     21.8        No           No
# 1       1010.6       1007.8     17.2     24.3        No           No
# 2       1007.6       1008.7     21.0     23.2        No           No
# 3       1017.6       1012.8     18.1     26.5        No           No
# 4       1010.8       1006.0     17.8     29.7        No           No

# %%
df = df.dropna(axis = 0)
df.shape
# Out:
# (112925, 17)

# %%
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['WindGustDir'] = le.fit_transform(df['WindGustDir'])
df['WindDir9am'] = le.fit_transform(df['WindDir9am'])
df['WindDir3pm'] = le.fit_transform(df['WindDir3pm'])
df['RainToday'] = le.fit_transform(df['RainToday'])
df['RainTomorrow'] = le.fit_transform(df['RainTomorrow'])

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 0     13.4     22.9       0.6           13           44.0          13
# 1      7.4     25.1       0.0           14           44.0           6
# 2     12.9     25.7       0.0           15           46.0          13
# 3      9.2     28.0       0.0            4           24.0           9
# 4     17.5     32.3       1.0           13           41.0           1
#
#    WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          14          20.0          24.0         71.0         22.0
# 1          15           4.0          22.0         44.0         25.0
# 2          15          19.0          26.0         38.0         30.0
# 3           0          11.0           9.0         45.0         16.0
# 4           7           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# 0       1007.7       1007.1     16.9     21.8          0             0
# 1       1010.6       1007.8     17.2     24.3          0             0
# 2       1007.6       1008.7     21.0     23.2          0             0
# 3       1017.6       1012.8     18.1     26.5          0             0
# 4       1010.8       1006.0     17.8     29.7          0             0

# %%
x = df.drop(['RainTomorrow'],axis = 1)
y = df["RainTomorrow"]

# %%
x.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 0     13.4     22.9       0.6           13           44.0          13
# 1      7.4     25.1       0.0           14           44.0           6
# 2     12.9     25.7       0.0           15           46.0          13
# 3      9.2     28.0       0.0            4           24.0           9
# 4     17.5     32.3       1.0           13           41.0           1
#
#    WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          14          20.0          24.0         71.0         22.0
# 1          15           4.0          22.0         44.0         25.0
# 2          15          19.0          26.0         38.0         30.0
# 3           0          11.0           9.0         45.0         16.0
# 4           7           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday
# 0       1007.7       1007.1     16.9     21.8          0
# 1       1010.6       1007.8     17.2     24.3          0
# 2       1007.6       1008.7     21.0     23.2          0
# 3       1017.6       1012.8     18.1     26.5          0
# 4       1010.8       1006.0     17.8     29.7          0

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x = 'MaxTemp', y = 'MinTemp', hue ='RainTomorrow',palette = 'Blues',data = df)
# Out:
# <AxesSubplot:xlabel='MaxTemp', ylabel='MinTemp'>

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x ='Humidity9am', y ='Temp9am', hue = 'RainTomorrow',palette = 'inferno',data = df)
# Out:
# <AxesSubplot:xlabel='Humidity9am', ylabel='Temp9am'>

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(x,y, test_size = 0.2)

# %%
x_train.shape
# Out:
# (90340, 16)

# %% [markdown]
# ## Define the model

# %%
def create_model(hp):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape=(16,)))
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
    model.add(keras.layers.Dense(units=hp_units, activation='relu'))
    model.add(keras.layers.Dense(
        units=hp.Int("units",min_value=12, max_value=250, step=32),
        activation='relu'
    ))
    model.add(keras.layers.Dense(1))
    
    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
        
        #loss=keras.losses.categorical_crossentropy(from_logits=True),
        loss=keras.losses.BinaryCrossentropy(),
        metrics=['accuracy']
    )
    return model
 
# model = KerasClassifier(build_fn=create_model)

# %%
tuner = kt.RandomSearch(
    hypermodel=create_model,
    objective="val_accuracy",
    max_trials=200,
)

# %% [markdown]
# Create a callback to stop training early after reaching a certain value for the validation loss.

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
# patience = 5 is no. of epochs (0-5)  in per search epochs (50)

# %%
tuner.search(x_train, y_train, epochs=50, validation_split=0.2, callbacks=[stop_early])
# Out:
# Trial 26 Complete [00h 01m 03s]
# val_accuracy: 0.7792229652404785
#
# Best val_accuracy So Far: 0.7792229652404785
# Total elapsed time: 01h 03m 04s
# INFO:tensorflow:Oracle triggered exit

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(tuner.get_best_hyperparameters)
# Out:
# <bound method BaseTuner.get_best_hyperparameters of <keras_tuner.tuners.randomsearch.RandomSearch object at 0x0000016F6008F880>>

# %%
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 288 and the optimal learning rate for the optimizer
# is 0.001.

# %% [markdown]
# ## Train the model
# Find the optimal number of epochs to train the model with the hyperparameters obtained from the search.

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/50
# 2259/2259 [==============================] - 31s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 2/50
# 2259/2259 [==============================] - 25s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 3/50
# 2259/2259 [==============================] - 26s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 4/50
# 2259/2259 [==============================] - 25s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 5/50
# 2259/2259 [==============================] - 25s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 6/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 7/50
# 2259/2259 [==============================] - 25s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 8/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792 3.4298 - accuracy
# Epoch 9/50
# 2259/2259 [==============================] - 30s 13ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 10/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 11/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 12/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 13/50
# 2259/2259 [==============================] - 30s 13ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 14/50
# 2259/2259 [==============================] - 28s 13ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 15/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 16/50
# 2259/2259 [==============================] - 26s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 17/50
# 2259/2259 [==============================] - 28s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 18/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 19/50
# 2259/2259 [==============================] - 26s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 20/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792curacy
# Epoch 21/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 22/50
# 2259/2259 [==============================] - 25s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 23/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 24/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 25/50
# 2259/2259 [==============================] - 25s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 26/50
# 2259/2259 [==============================] - 26s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 27/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 28/50
# 2259/2259 [==============================] - 29s 13ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 29/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 30/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 31/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 32/50
# 2259/2259 [==============================] - 26s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792 - los - ETA: 3s - los - ETA
# Epoch 33/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 34/50
# 2259/2259 [==============================] - 25s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 35/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 36/50
# 2259/2259 [==============================] - 28s 13ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 37/50
# 2259/2259 [==============================] - 26s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 38/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 39/50
# 2259/2259 [==============================] - 26s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 40/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 41/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 42/50
# 2259/2259 [==============================] - 31s 14ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 43/50
# 2259/2259 [==============================] - 25s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 44/50
# 2259/2259 [==============================] - 26s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 45/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 46/50
# 2259/2259 [==============================] - 34s 15ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 47/50
# 2259/2259 [==============================] - 26s 11ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 48/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 49/50
# 2259/2259 [==============================] - 27s 12ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Epoch 50/50
# 2259/2259 [==============================] - 28s 13ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792
# Best epoch: 1

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(x_train, y_train, epochs=best_epoch, validation_split=0.2)
# Out:
# 2259/2259 [==============================] - 32s 13ms/step - loss: 3.4292 - accuracy: 0.7777 - val_loss: 3.4055 - val_accuracy: 0.7792

# %%
eval_result = hypermodel.evaluate(x_test, y_test)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 706/706 [==============================] - 4s 6ms/step - loss: 3.3896 - accuracy: 0.7803
# [test loss, test accuracy]: [3.3895998001098633, 0.7802523970603943]
